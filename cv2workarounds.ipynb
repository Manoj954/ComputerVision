# %%
import cv2

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pylab as pl
from PIL import Image
import numpy as np
import pylab

# %%
imgpath="D:\\Mark\\R\\Machine-Learning with R\\R-with-Machine-learning\\Data\\sampleImage.png"
img = Image.open(imgpath).convert('L')
z   = np.asarray(img)
mydata = z[::1,::1]
fig = pl.figure(facecolor='w')
ax1 = fig.add_subplot(1,2,1)
im = ax1.imshow(mydata,interpolation='nearest',cmap=pl.cm.jet)
ax1.set_title('2D')

ax2 = fig.add_subplot(1,2,2,projection='3d')
x,y = np.mgrid[:mydata.shape[0],:mydata.shape[1]]
ax2.plot_surface(x,y,mydata,cmap=pl.cm.jet,rstride=1,cstride=1,linewidth=0.,antialiased=False)
ax2.set_title('3D')
ax2.set_zlim3d(0,100)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-af2885a58948> in <module>()
#      13 ax2.set_title('3D')
#      14 ax2.set_zlim3d(0,100)
# ---> 15 pl.show()
#
# ~\AppData\Local\Continuum\anaconda3\envs\condaOpenCV\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~\AppData\Local\Continuum\anaconda3\envs\condaOpenCV\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ...

# %%
from matplotlib.cbook import get_sample_data
from matplotlib._png import read_png
fn = get_sample_data(imgpath, asfileobj=False)
img = read_png(fn)
x, y = ogrid[0:img.shape[0], 0:img.shape[1]]
ax = gca(projection='3d')
ax.plot_surface(x, y, 10, rstride=5, cstride=5, facecolors=img)
show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b713cdc828e7> in <module>()
#       2 from matplotlib._png import read_png
#       3 fn = get_sample_data(imgpath, asfileobj=False)
# ----> 4 img = read_png(fn)
#       5 x, y = ogrid[0:img.shape[0], 0:img.shape[1]]
#       6 ax = gca(projection='3d')
#
# ValueError: invalid PNG header

# %%
from pylab import *

# %%
x, y = ogrid[0:z.shape[0], 0:z.shape[1]]

# %%
ax = gca(projection='3d')

# %%
ax.plot_surface(x, y, 10, rstride=5, cstride=5, facecolors=img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6b219e3e8556> in <module>()
# ----> 1 ax.plot_surface(x, y, 10, rstride=5, cstride=5, facecolors=img)
#
# ~\AppData\Local\Continuum\anaconda3\envs\condaOpenCV\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1633         had_data = self.has_data()
#    1634
# -> 1635         if Z.ndim != 2:
#    1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#
# AttributeError: 'int' object has no attribute 'ndim'

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy.ndimage as ndimage

# %%
mat = imread(imgpath,0)
mat = mat[:,:,0] # get the first channel
rows, cols = mat.shape
xv, yv = np.meshgrid(range(cols), range(rows)[::-1])
 
blurred = ndimage.gaussian_filter(mat, sigma=(5, 5), order=0)
fig = plt.figure(figsize=(9,9))
 
ax = fig.add_subplot(221)
ax.imshow(mat, cmap='gray')
 
ax = fig.add_subplot(222, projection='3d')
ax.elev= 75
ax.plot_surface(xv, yv, mat)
 
ax = fig.add_subplot(223)
ax.imshow(blurred, cmap='gray')
 
ax = fig.add_subplot(224, projection='3d')
ax.elev= 75
ax.plot_surface(xv, yv, blurred)
plt.show()

# %%
            block_size = 239
            constant = 2            
            frame = cv2.cvtColor(mat, cv2.COLOR_BGR2GRAY)
            windowNames=['Thresh Mean', 'Gaussian']
            th1 = cv2.adaptiveThreshold(frame, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
            th2 = cv2.adaptiveThreshold(frame, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, constant)
            #print ('threshold completed')
            output= [th1, th2]
            #print(len(output))
            for i in range(2):                
                #print (i)
                cv2.imshow(windowNames[i], output[i])

            if cv2.waitKey(1)==27:
                break
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-948e717f0224> in <module>()
#       1 block_size = 239
#       2 constant = 2
# ----> 3 frame = cv2.cvtColor(mat, cv2.COLOR_BGR2GRAY)
#       4 windowNames=['Thresh Mean', 'Gaussian']
#       5 th1 = cv2.adaptiveThreshold(frame, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
#
# error: ..\..\..\modules\imgproc\src\color.cpp:7456: error: (-215) scn == 3 || scn == 4 in function cv::ipp_cvtColor

# %%
img = cv2.imread(imgpath, 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)
plt.show()

# %%
block_size = 255
constant = 2

# %%
th1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant)
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, constant)

# %%
output = [img, th1, th2]
titles=['Original', 'Thresh Mean', 'Gaussian']

# %%
for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(output[i], cmap='gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
plt.imshow(th1)
plt.show()

# %%
plt.imshow(th2, cmap='gray')
plt.show()

# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os

# %%
text = pytesseract.image_to_string(Image.open(imgpath))
print(text)
# Out:
# | eae Ty
#
# erereyei fe
#
#
#
#
#
# Pye aia) ican
